# %% [markdown]
# # Bear specialist training
# Use a private Kaggle notebook with GPU enabled. Add the repository or data as a private input.

# %%
# %cd /kaggle/working
# !git clone https://github.com/drtassio/BinanceFuturesTrader.git repo
# %cd /kaggle/working/repo
# !pip install -q -r cloud/requirements-cloud.txt

# %%
# !python cloud/train_agent.py --agent bear --timesteps 100000
# !tar -czf /kaggle/working/bear_artifacts.tgz models_ai/bear_specialist_sac.zip models_ai/bear_specialist_scaler.joblib cloud/artifacts/bear_training_report.json
