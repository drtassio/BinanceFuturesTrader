# %% [markdown]
# # Bull specialist training
# Run this notebook on a GPU runtime. Keep the notebook private and never upload `.env`.

# %%
# !git clone https://github.com/drtassio/BinanceFuturesTrader.git /content/BinanceFuturesTrader
# %cd /content/BinanceFuturesTrader
# !pip install -q -r cloud/requirements-cloud.txt

# %%
# !python cloud/train_agent.py --agent bull --timesteps 100000
# !tar -czf /content/bull_artifacts.tgz models_ai/bull_specialist_sac.zip models_ai/bull_specialist_scaler.joblib cloud/artifacts/bull_training_report.json
